# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
def wrangle (filename, encoding = None, dropna_columnnames = None, change_column_name= None, date_column= None, remove_duplicated_rows_columnsname = None):
    # Loading Data from csv file
    df = pd.read_csv(filename, encoding= encoding)

    ### Get Orders NaN Rows
    df.dropna(subset= dropna_columnnames, inplace=True)

    # Rename Columns
    df = df.rename(columns= change_column_name)
    
    # Change OrderDate and ID Columns type to Date, integer
    df[date_column] = pd.to_datetime(df[date_column])    

    #Drop dupliacted rows
    df = df.drop_duplicates(subset= remove_duplicated_rows_columnsname)

       
    #Strip and lowercase columns names
    df.columns = df.columns.str.strip().str.lower()
    
    return df

# %%
orders = wrangle('all_data.csv', encoding= 'latin-1' , dropna_columnnames= ['OrderID'], change_column_name= {'City.1' : 'SuppCity', 'Country.1' : 'SuppCountry', 'Phone.1' : 'Supp_Phone'}, date_column= 'OrderDate', remove_duplicated_rows_columnsname= ['OrderID'])
orders
# Out:
#       customerid  firstname   lastname            city      country  \
# 0           85.0       Paul    Henriot           Reims       France
# 3           79.0      Karin    Josephs         Münster      Germany
# 5           34.0      Mario     Pontes  Rio de Janeiro       Brazil
# 8           84.0       Mary    Saveley            Lyon       France
# 11          76.0    Pascale   Cartrain       Charleroi      Belgium
# ...          ...        ...        ...             ...          ...
# 2121        58.0  Guillermo  Fern?ndez     México D.F.       Mexico
# 2123        73.0      Jytte   Petersen       Kobenhavn      Denmark
# 2124        68.0    Michael       Holz          Genève  Switzerland
# 2127         9.0   Laurence    Lebihan       Marseille       France
# 2130        65.0      Paula     Wilson     Albuquerque          USA
#
#                   phone  orderid  orderdate  ordernumber  totalamount  ...  \
# 0           26.47.15.10      1.0 2012-07-04     542378.0        440.0  ...
# 3           0251-031259      2.0 2012-07-05     542379.0       1863.4  ...
# 5         (21) 555-0091      3.0 2012-07-08     542380.0       1813.0  ...
# 8           78.32.54.86      4.0 2012-07-08     542381.0        670.8  ...
# 11    (071) 23 67 22 20      5.0 2012-07-09     542382.0       3730.0  ...
# ...                 ...      ...        ...          ...          ...  ...
# 2121       (5) 552-3745    826.0 2014-05-05     543203.0        300.0  ...
# 2123        31 12 34 56    827.0 2014-05-06     543204.0        244.3  ...
# 2124        0897-034214    828.0 2014-05-06     543205.0        586.0  ...
# 2127        91.24.45.40    829.0 2014-05-06     543206.0       1057.0  ...
# 2130     (505) 555-5939    830.0 2014-05-06     543207.0       1374.6  ...
#
#       unitprice             package  isdiscontinued supplierid  \
# 0         21.00           1 kg pkg.           False        5.0
# 3         23.25    40 - 100 g pkgs.           False        6.0
# 5          9.65     12 - 12 oz cans           False       19.0
# 8         21.00    24 - 500 g pkgs.           False        9.0
# 11        81.00       30 gift boxes           False        8.0
# ...         ...                 ...             ...        ...
# 2121      21.00           1 kg pkg.           False        5.0
# 2123      17.45    32 - 500 g boxes           False        7.0
# 2124      19.00  24 - 12 oz bottles           False        1.0
# 2127      25.00      12 - 8 oz jars           False        3.0
# 2130       7.75  24 - 0.5 l bottles           False       12.0
#
#                              companyname                 contactname  \
# 0     Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
# 3                               Mayumi's                 Mayumi Ohno
# 5            New England Seafood Cannery               Robb Merchant
# 8                       PB Kn?ckebr?d AB               Lars Peterson
# 11              Specialty Biscuits, Ltd.                Peter Wilson
# ...                                  ...                         ...
# 2121  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
# 2123                       Pavlova, Ltd.                 Ian Devling
# 2124                      Exotic Liquids            Charlotte Cooper
# 2127           Grandma Kelly's Homestead               Regina Murphy
# 2130   Plutzer Lebensmittelgro?m?rkte AG                 Martin Bein
#
#         suppcity suppcountry      supp_phone             fax
# 0         Oviedo       Spain  (98) 598 76 54             NaN
# 3          Osaka       Japan   (06) 431-7877             NaN
# 5         Boston         USA  (617) 555-3267  (617) 555-3389
# 8       G?teborg      Sweden   031-987 65 43   031-987 65 91
# 11    Manchester          UK  (161) 555-4448             NaN
# ...          ...         ...             ...             ...
# 2121      Oviedo       Spain  (98) 598 76 54             NaN
# 2123   Melbourne   Australia   (03) 444-2343   (03) 444-6588
# 2124      London          UK  (171) 555-2222             NaN
# 2127   Ann Arbor         USA  (313) 555-5735  (313) 555-3349
# 2130   Frankfurt     Germany    (069) 992755             NaN
#
# [830 rows x 22 columns]
